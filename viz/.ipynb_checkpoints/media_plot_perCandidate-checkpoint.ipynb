# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

with open(r'D:\TFG\tfg_git\data\news\news3.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
# extract domain from urls

from urllib.parse import urlparse

domain = urlparse(data["url"][1]).netloc
print(domain) # --> www.example.test
# Out:
# www.breitbart.com

# %%
domains = []
for i in data["url"]: 
    domains.append(urlparse(i).netloc)

# %%
domains_f = []
for i in domains:
    domains_f.append(i.replace("www.","").replace(".com",""))

# %%
top10media = pd.Series(domains_f).value_counts()[0:10]

# %%
len( pd.Series(domains).value_counts())
# Out:
# 1408

# %%
print(top10media)
# Out:
# usnews            1086
# news.yahoo         800
# rawstory           744
# medium             355
# breitbart          338
# msn                315
# washingtonpost     312
# freerepublic       299
# arcamax            290
# politico           288
# dtype: int64

# %%
top10media.tolist()
# Out:
# [1086, 800, 744, 355, 338, 315, 312, 299, 290, 288]

# %%
au = top10media.index.tolist()
n = top10media.tolist()
# Figure Size
fig, ax = plt.subplots(figsize =(16, 10))
 
# Horizontal Bar Plot
ax.barh(au, n, color='lightblue')
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(visible = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
ax.set_title("Principales medios en el corpus", y=0.98, fontsize=14)
 
# Add Text watermark
#fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 12,
#         color ='grey', ha ='right', va ='bottom',
#         alpha = 0.7)
 
# Show Plot
plt.show()

# %%
fig.savefig('media_countplot.jpg', dpi=600)

# %%
sum(top10media.tolist())/26501*100
# Out:
# 18.2144070035093

# %%
data
# Out:
#                                                      url           published  \
# 0      https://www.washingtontimes.com/news/2020/feb/... 2020-02-20 22:17:00
# 1      https://www.breitbart.com/politics/2020/02/20/... 2020-02-20 00:00:00
# 2      https://www.freep.com/story/news/politics/elec... 2020-02-20 22:19:00
# 3      https://www.freep.com/story/news/politics/elec... 2020-02-20 21:01:00
# 4      https://www.freep.com/story/news/politics/elec... 2020-02-20 22:19:00
# ...                                                  ...                 ...
# 33394  https://www.usnews.com/news/best-states/missou... 2020-02-10 18:13:00
# 33395  https://www.usnews.com/news/best-states/pennsy... 2020-02-10 16:54:00
# 3      WASHINGTON – Michigan, Pennsylvania and Wiscon...            freep.com
# 4      President Donald Trump is in Colorado Thursday...            freep.com
# ...                                                  ...                  ...
# 33394  Missouri News Missouri Ag Agency Has Backlog o...           usnews.com
# 33395  Pennsylvania News Burglary, Theft-Related Char...           usnews.com
# 33396  Video: Associated Press Biden gets hopeful Vir...            wusa9.com
# 33397  Biden Says He Will Send 35,000 to 60,000 More ...          cnsnews.com
# 33398  Rhode Island News Event Planned to Get Input o...           usnews.com
#
#        domainRank        timeDiff  authorInText  twAccountMentions  \
# 0            3106 0 days 02:13:41          True                 []
# 1             967 1 days 00:40:42         False  [@RealKyleMorris]
# 2            2980 0 days 02:38:47         False                 []
# 3            2980 0 days 04:37:47         False                 []
# 4            2980 0 days 03:20:38         False                 []
# ...           ...             ...           ...                ...
# 33394        1027 0 days 00:28:42          True                 []
# 33395        1027 0 days 01:50:13          True                 []
# 33396       39353 0 days 00:07:51         False                 []
# 33397       12476 2 days 03:13:07         False                 []
# 33398        1027 0 days 02:55:12          True                 []
#
#                                               clean_text  \
# 0      By THE WASHINGTON TIMES - - Thursday, February...
# 1      Poll: Trump Leads in Wisconsin, Trails Democra...
# 2      President Donald Trump is in Colorado Thursday...
# 3      WASHINGTON  Michigan, Pennsylvania and Wiscons...
# 4      President Donald Trump is in Colorado Thursday...
# ...                                                  ...
# 33394  Missouri News Missouri Ag Agency Has Backlog o...
# 33395  Pennsylvania News Burglary, Theft-Related Char...
# 33396  Video: Associated Press Biden gets hopeful Vir...
# 33397  Biden Says He Will Send 35,000 to 60,000 More ...
# 33398  Rhode Island News Event Planned to Get Input o...
#
#                                            personCounter
# 0      {'Michael Bloomberg': 1, 'Bernie Sanders': 1, ...
# 1      {'Donald Trump': 1, 'Trump': 6, 'Joe Biden': 1...
# 2      {'Donald Trump': 9, 'Fox': 2, 'Trump': 25, 'Se...
# 3      {'Donald Trump': 1, 'Hillary Clinton': 1, 'Cli...
# 4      {'Donald Trump': 11, 'Cory Gardner': 2, 'Gardn...
# ...                                                  ...
# 33394  {'Sami Jo Freeman': 1, 'Casey Leins': 2, 'Harv...
# 33395  {'Donald Trump': 2, 'More': 1, 'Shawn Christy'...
# 33396  {'Biden': 4, 'Terry McAuliffe': 2, 'Nick Boyki...
# 33397     {'Biden': 5, 'Joe Biden': 1, 'Joe Biden's': 1}
# 33398  {'Angelica Infante-Green': 1, 'Harrison Peters...
#
# [26517 rows x 15 columns]

# %%
lens = []
for i in data.text: 
    lens.append(len(i.split()))

# %%
sum(lens)/len(lens)
# Out:
# 1073.6159067767846
